# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,100,11)
x
y=x**3
y
# Out:
# array([      0.,    1000.,    8000.,   27000.,   64000.,  125000.,
#         216000.,  343000.,  512000.,  729000., 1000000.])

# %%
plt.plot(x,y)
plt.title("hello")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')
