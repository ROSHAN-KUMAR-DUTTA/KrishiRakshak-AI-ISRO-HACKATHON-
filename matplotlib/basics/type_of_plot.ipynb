# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
x
y=x**3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd1795d8680>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fd1794d0ad0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fd1794d0200>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd1794d10d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd1794d1370>],
#  'means': []}

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,1,1])
ax.plot(x,y)
plt.savefig("basicplot.jpeg")
