# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
x
y=x**3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
fig=plt.figure(figsize=(6,8),dpi=100)
axis1=fig.add_axes([0.1,0.1,0.5,1])
axis1.plot(x,y)
axis2=fig.add_axes([0.5,0.3,0.3,0.3])
axis2.plot(x,y)
